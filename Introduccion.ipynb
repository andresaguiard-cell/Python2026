# %% [markdown]
# ## Introducción a Python <br>
# Pyhton es un lenguaje de **Programación** de alto nivel enfocado en la inteligencia artificial. <br>
# También me permite generar apliaciones de escritorio, web, moviles con programación orientada a objetos. <br>
# **Programador** Andres Aguiar

# %%
# Aquí se escribe un comentario de una sola linea
print("Hola esto es un mensaje")
# Out:
# Hola esto es un mensaje

# %%
print("Sebastian Sampedro")
# Out:
# Sebastian Sampedro

# %% [markdown]
# https://github.com/andresaguiard-cell/Python2026/blob/main/Introduccion.ipynb
