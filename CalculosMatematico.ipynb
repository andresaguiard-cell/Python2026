# %% [markdown]
# **<h1 align="center">EJERCICIOS EN CLASE</h1>**
#
# **nombre:** *Andres Aguiar*
#
# **fecha:** *12-01-2026*

# %% [markdown]
# 1. Crear un programa donde se inserten dos valores , y se demuestre si el primer valor es mayor que el segundo valor

# %%
x = int(input("inserte un valor:"))
y = int(input("inserte un valor:"))

print('x > y es ', x > y)
# Out:
# inserte un valor: 13
# inserte un valor: 15
# x > y es  False

# %% [markdown]
# 2. Ingresar por teclado la fecha actual dia-mes-año tambien fehca de nacimiento de una persona y calcular cuantos años tiene

# %% [markdown]
# **MODELO 1**

# %%
x = int(input(" ingrese fecha actual: "))
y = int(input(" fecha de nacimiento: "))

print(f"edad actual: {x-y}")
# Out:
#  ingrese fecha actual:  2026
#  fecha de nacimiento:  2006
# edad actual: 20

# %% [markdown]
# **MODELO 2**

# %%
print(" Datos Fecha Actual")
d1 = int(input(" Día: "))
m1 = int(input(" Mes: "))
a1 = int(input(" Año: "))

print(" Datos Nacimiento ")
d2 = int(input(" Día: "))
m2 = int(input(" Mes: "))
a2 = int(input(" Año: "))

dias_final= d1-d2
meses_final= m1-m2
años_final= a1-a2

print(f"\n Edad calculada:{años_final} años,{meses_final} meses,{dias_final} días.")
# Out:
#  Datos Fecha Actual
#  Día:  12
#  Mes:  01
#  Año:  2026
#  Datos Nacimiento
#  Día:  14
#  Mes:  02
#  Año:  2006
#  Edad calculada:20 años,-1 meses,-2 días.

# %% [markdown]
# 3. Elaborar un programa en python que permita ingresar el radio y la altura de un cilindro y calcular el volumen del cilindro. Sabiendo que la formula es (V= π* r^2 *h)

# %%
import math

x = int(input("inserte el radio:"))
y = int(input("inserte la altura:"))

print(f" Volumen del cilindro: {math.pi * x**2 * y}")
# Out:
# inserte el radio: 13
# inserte la altura: 25
#  Volumen del cilindro: 13273.228961416877

# %% [markdown]
# 4. Elaborar un programa que permita convertir una distancia medida en metros ha **centimetros, milimetros y kilometros**.El usuario debe ingresar el valor en metros y el programadebe mostrar las 3 equiuvalencias correspondientes

# %%
xm = int(input("Inserte el valor en metros: "))

cm = x * 100
mm = x * 1000
km = x / 1000

print(f"METROS A CENTIMETROS: {cm} cm")
print(f"METROS A MILIMETROS:  {mm} mm")
print(f"METROS A KILOMETROS:  {km} km")
# Out:
# Inserte el valor en metros:  55
# METROS A CENTIMETROS: 2500 cm
# METROS A MILIMETROS:  25000 mm
# METROS A KILOMETROS:  0.025 km
