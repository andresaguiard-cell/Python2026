# %% [markdown]
# ## TERCER MODULO - PAO25_25_07_Python_Pandas
#
# *Andres Aguiar*

# %% [markdown]
# ### 1 Pandas

# %% [markdown]
# * Librería (de facto estándar) para estructurar datos tabulares
# * Multivariable (string, int, float, bool…)
# * Dos clases:– Series (1 dimensión)– DataFrames (2+ dimensiones

# %%
 # librería externa
import pandas as pd
from pandas import Series, DataFrame

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ### 2 Series

# %% [markdown]
# * Datos unidimensionales (similar a NumPy)
# * Elementos + índices modificables

# %%
countries = pd.Series(['Spain','Andorra','Gibraltar','Portugal','France'])
print(countries)
# Out:
# 0        Spain
# 1      Andorra
# 2    Gibraltar
# 3     Portugal
# 4       France
# dtype: object

# %%
# especificando el índice
countries = pd.Series(['Spain','Andorra','Gibraltar','Portugal','France'],
index=range(10,60,10))
print(countries)
# Out:
# 10        Spain
# 20      Andorra
# 30    Gibraltar
# 40     Portugal
# 50       France
# dtype: object

# %%
# los índices pueden ser de más tipos
football_cities = pd.Series(['Barcelona','Madrid','Valencia','Sevilla'],
index=['a','b','c','d'])
print(football_cities)
# Out:
# a    Barcelona
# b       Madrid
# c     Valencia
# d      Sevilla
# dtype: object

# %%
# Atributos
football_cities.name = 'Ciudades con dos equipos en primera' # nombrar la Serie
football_cities.index.name = 'Id' # Describir los índices
print(football_cities)
# Out:
# Id
# a    Barcelona
# b       Madrid
# c     Valencia
# d      Sevilla
# Name: Ciudades con dos equipos en primera, dtype: object

# %%
# acceso similar a NumPy o listas, según posición (depecrated)
print(football_cities.iloc[2])
# acceso a través del índice semántico
print(football_cities['c'])
print(football_cities['c'] == football_cities.iloc[2])
# Out:
# Valencia
# Valencia
# True

# %% [markdown]
# ### 3 Tratamiento similar a ndarray

# %%
# múltiple recolección de elementos
print(football_cities[['a','c']])
print(football_cities.iloc[[0,3]])
# Out:
# Id
# a    Barcelona
# c     Valencia
# Name: Ciudades con dos equipos en primera, dtype: object
# Id
# a    Barcelona
# d      Sevilla
# Name: Ciudades con dos equipos en primera, dtype: object

# %%
# slicing
print(football_cities[:'c']) # incluye ambos extremos con el indice semantico
print(football_cities[:2])
# Out:
# Id
# a    Barcelona
# b       Madrid
# c     Valencia
# Name: Ciudades con dos equipos en primera, dtype: object
# Id
# a    Barcelona
# b       Madrid
# Name: Ciudades con dos equipos en primera, dtype: object

# %%
#cast a list
lista = list(football_cities[:'c'])
print(lista)
print(type(lista))
# Out:
# ['Barcelona', 'Madrid', 'Valencia']
# <class 'list'>

# %%
type(football_cities[:'c'])
# Out:
# pandas.core.series.Series

# %%
#cast a ndarray
import numpy as np
cities = np.array(football_cities[:'c'])
print(cities)
print(type(cities))
# Out:
# ['Barcelona' 'Madrid' 'Valencia']
# <class 'numpy.ndarray'>

# %%
# cas a dictionary
lista = dict(football_cities[:'c'])
print(lista)
# Out:
# {'a': 'Barcelona', 'b': 'Madrid', 'c': 'Valencia'}

# %%
# uso de masks para seleccionar
fibonacci = pd.Series([0, 1, 1, 2, 3, 5, 8, 13, 21])
print(fibonacci)
mask = fibonacci > 10
print(mask)
print(fibonacci[mask])
dst = pd.Series([13,21])
print(dst)
dst.equals(fibonacci)
fb = fibonacci[mask]
fb.reset_index(drop=True, inplace=True)
print(fb)
dst.equals(fb)
# Out:
# 0     0
# 1     1
# 2     1
# 3     2
# 4     3
# 5     5
# 6     8
# 7    13
# 8    21
# dtype: int64
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8     True
# dtype: bool
# 7    13
# 8    21
# dtype: int64
# 0    13
# 1    21
# dtype: int64
# 0    13
# 1    21
# dtype: int64
# True

# %%
# aplicar funciones de numpy a la serie
import numpy as np
print(np.sum(fibonacci))
# Out:
# 54

# %%
#filtrado con np.where
distances = pd.Series([12.1,np.nan,12.8,76.9,6.1,7.2])
valid_distances = np.where(pd.notnull(distances),distances,2)
print(valid_distances)
print(type(valid_distances))
# Out:
# [12.1  2.  12.8 76.9  6.1  7.2]
# <class 'numpy.ndarray'>

# %% [markdown]
# ### 3.0.1 Iteración

# %%
# iterar sobre elementos
for value in fibonacci:
 print('Value: ' + str(value))
# # iterar sobre indices
for index in fibonacci.index:
 print('Index: ' + str(index))
# Out:
# Value: 0
# Value: 1
# Value: 1
# Value: 2
# Value: 3
# Value: 5
# Value: 8
# Value: 13
# Value: 21
# Index: 0
# Index: 1
# Index: 2
# Index: 3
# Index: 4
# Index: 5
# Index: 6
# Index: 7
# Index: 8

# %%
# iterar sobre elementos e índices al mismo tiempo
for index, value in fibonacci.items():
 print('Index: ' + str(index) + ' Value: ' + str(value))
# Out:
# Index: 0 Value: 0
# Index: 1 Value: 1
# Index: 2 Value: 1
# Index: 3 Value: 2
# Index: 4 Value: 3
# Index: 5 Value: 5
# Index: 6 Value: 8
# Index: 7 Value: 13
# Index: 8 Value: 21

# %%
for index, value in zip(fibonacci.index, fibonacci):
 print('Index: ' + str(index) + ' Value: ' + str(value))
# Out:
# Index: 0 Value: 0
# Index: 1 Value: 1
# Index: 2 Value: 1
# Index: 3 Value: 2
# Index: 4 Value: 3
# Index: 5 Value: 5
# Index: 6 Value: 8
# Index: 7 Value: 13
# Index: 8 Value: 21

# %% [markdown]
# ### 3.1 Series como diccionarios
# * Interpretar el índice como clave
# * Acepta operaciones para diccionarios

# %%
# crear una serie a partir de un diccionario
serie = pd.Series( { 'Carlos' : 100, 'Marcos': 98} )
print(serie.index)
print(serie.values)
print(serie)
print(type(serie))
# Out:
# Index(['Carlos', 'Marcos'], dtype='object')
# [100  98]
# Carlos    100
# Marcos     98
# dtype: int64
# <class 'pandas.core.series.Series'>

# %%
# añade y elimina elementos a través de índices
serie['Pedro'] = 12
serie['Pedro']=15
del serie['Marcos']
print(serie)
# Out:
# Carlos    100
# Pedro      15
# dtype: int64

# %%
# query una serie
# print(serie['Marcos'])
if 'Marcos' in serie:
 print(serie['Marcos'])
print(serie)
# Out:
# Carlos    100
# Pedro      15
# dtype: int64

# %% [markdown]
# ### 3.2 Operaciones entre series

# %%
# suma de dos series
# suma de valores con el mismo índice (NaN si no aparece en ambas)
serie1 = pd.Series([10,20,30,40], index=range(4) )
serie2 = pd.Series([1,2,3], index=range(3) )
suma = serie1 + serie2
print(suma)
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3     NaN
# dtype: float64

# %%
# resta de series (similar a la suma)
print(serie1- serie2)
# Out:
# 0     9.0
# 1    18.0
# 2    27.0
# 3     NaN
# dtype: float64

# %%
# operaciones de pre-filtrado
result = serie1 + serie2
result[pd.isnull(result)] = 0 # mask con isnull()
print(result)
# Out:
# 0    11.0
# 1    22.0
# 2    33.0
# 3     0.0
# dtype: float64

# %% [markdown]
# ### 3.2.1 Diferencias entre Pandas Series y diccionario

# %% [markdown]
# * Diccionario, es una estructura que relaciona las claves y los valores de forma arbitraria.
# * Series, estructura de forma estricta listas de valores con listas de índice asignado en la posición.
# * Series, es más eficiente para ciertas operaciones que los dicionarios.
# * Enlas Series los valores de entrada pueden ser listas o Numpy arrays.
# * EnSeries los índices semánticos pueden ser integers o caracteres, en los valores igual.
# * Series se podría entender entre una lista y un diccionario Python, pero es de una dimensión.

# %% [markdown]
# ### 4 DataFrame

# %% [markdown]
# * Datos tabulares (filas x columnas)
# * Columnas: Series con índices compartidos

# %%
# crear un DataFrame a partir de un diccionario de elementos de la misma longitud
diccionario = { "Nombre" : ["Marisa","Laura","Manuel"],
"Edad" : [34,29,12] }

print(diccionario)

# las claves identifican columnas
frame = pd.DataFrame(diccionario)
display(frame)
# Out:
# {'Nombre': ['Marisa', 'Laura', 'Manuel'], 'Edad': [34, 29, 12]}
#    Nombre  Edad
# 0  Marisa    34
# 1   Laura    29
# 2  Manuel    12

# %%
# crear un DataFrame a partir de un diccionario de elementos de la misma longitud
diccionario = { "Nombre" : ["Marisa","Laura","Manuel"],
"Edad" : [34,29,12] }

# las claves identifican columnas
frame = pd.DataFrame(diccionario, index = ['a', 'b', 'c'])
display(frame)
# Out:
#    Nombre  Edad
# a  Marisa    34
# b   Laura    29
# c  Manuel    12

# %%
# además de `index`, el parámetro `columns` especifica el número y orden de las columnas
frame = pd.DataFrame(diccionario, columns = ['Nacionalidad', 'Nombre', 'Edad', 'Profesión', 'Genero'])

display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesión Genero
# 0          NaN  Marisa    34       NaN    NaN
# 1          NaN   Laura    29       NaN    NaN
# 2          NaN  Manuel    12       NaN    NaN

# %%
# acceso a columnas
nombres = frame['Nombre']
display(nombres)
5
print(type(nombres))
edades = frame['Edad']
display(edades)
print(type(edades))
# Out:
# 0    Marisa
# 1     Laura
# 2    Manuel
# Name: Nombre, dtype: object
# <class 'pandas.core.series.Series'>
# 0    34
# 1    29
# 2    12
# Name: Edad, dtype: int64
# <class 'pandas.core.series.Series'>

# %%
#siempre que el nombre de la columna lo permita (espacios, ...)
nombres = frame.Profesion
display(nombres)
type(nombres)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8888\1774422287.py in ?()
#       1 #siempre que el nombre de la columna lo permita (espacios, ...)
# ----> 2 nombres = frame.Profesion
#       3 display(nombres)
#       4 type(nombres)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Profesion'

# %%
# acceso al primer nombre del DataFrame frame??
print(frame['Nombre'][0])
print(frame.Nombre[0])
print(nombres[0])
# Out:
# Marisa
# Marisa
# Marisa

# %% [markdown]
# ### 4.0.1 Formas de crear un DataFrame

# %% [markdown]
# * Con una Serie de pandas
# * Lista de diccionarios
# * Dicionario de Series de Pandas
# * Con un array de Numpy de dos dimensiones
# * Con array estructurado de Numpy

# %% [markdown]
# ### 4.1 Modificar DataFrames

# %%
# añadir columnas
diccionario = { "Nombre" : ["Marisa","Laura","Manuel"],
"Edad" : [34,29,12] }
frame = pd.DataFrame(diccionario, columns=['Nacionalidad', 'Nombre',
'Edad','Profesion', 'Direccion'])
frame['Direccion'] = 'Desconocida'
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion    Direccion
# 0          NaN  Marisa    34       NaN  Desconocida
# 1          NaN   Laura    29       NaN  Desconocida
# 2          NaN  Manuel    12       NaN  Desconocida

# %%
lista_direcciones = [
    'Rue 13 del Percebe, 13',
    'Evergreen Terrace, 3',
    'Av de los Rombos, 12'
]

# %%
frame['Direccion'] = lista_direcciones
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion               Direccion
# 0          NaN  Marisa    34       NaN  Rue 13 del Percebe, 13
# 1          NaN   Laura    29       NaN    Evergreen Terrace, 3
# 2          NaN  Manuel    12       NaN    Av de los Rombos, 12

# %%
# añadir fila (requiere todos los valores)
user_2 = ['Alemania','Klaus',20, 'none','Desconocida']
frame.loc[3] = user_2
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion               Direccion
# 0          NaN  Marisa    34       NaN  Rue 13 del Percebe, 13
# 1          NaN   Laura    29       NaN    Evergreen Terrace, 3
# 2          NaN  Manuel    12       NaN    Av de los Rombos, 12
# 3     Alemania   Klaus    20      none             Desconocida

# %%
# eliminar fila (similar a Series)
frame = pd.DataFrame(diccionario,columns=['Nacionalidad', 'Nombre', 'Edad',
'Profesion'])
frame = frame.drop(2) # por qué necesitamos reasignar el frame?
display(frame)
frame.drop('Nombre', axis = 1, inplace = True)
display(frame)
# Out:
#   Nacionalidad  Nombre  Edad Profesion
# 0          NaN  Marisa    34       NaN
# 1          NaN   Laura    29       NaN
#   Nacionalidad  Edad Profesion
# 0          NaN    34       NaN
# 1          NaN    29       NaN

# %%
#eliminar columna
del frame['Profesion']
display(frame)
# Out:
#   Nacionalidad  Edad
# 0          NaN    34
# 1          NaN    29

# %%
# acceder a la traspuesta (como una matriz)
display(frame.T)
# Out:
#                 0    1
# Nacionalidad  NaN  NaN
# Edad           34   29

# %% [markdown]
# ### 4.2 Iteración

# %%
# iteración sobre el DataFrame?
frame = pd.DataFrame(diccionario, columns=['Nacionalidad', 'Nombre', 'Edad',
'Profesion'])
display(frame)
for a in frame:
 print(a) 
print(type(a))
# Out:
#   Nacionalidad  Nombre  Edad Profesion
# 0          NaN  Marisa    34       NaN
# 1          NaN   Laura    29       NaN
# 2          NaN  Manuel    12       NaN
# Nacionalidad
# Nombre
# Edad
# Profesion
# <class 'str'>

# %%
# iteracion sobre filas
for value in frame.values:
 print(value)
print(type(value))
# Out:
# [nan 'Marisa' 34 nan]
# [nan 'Laura' 29 nan]
# [nan 'Manuel' 12 nan]
# <class 'numpy.ndarray'>

# %%
# iterar sobre filas y luego sobre cada valor?
for values in frame.values:
 for value in values:
  print(value)
# Out:
# nan
# Marisa
# 34
# nan
# nan
# Laura
# 29
# nan
# nan
# Manuel
# 12
# nan

# %% [markdown]
# ### 4.3 Indexación y slicing con DataFrames

# %%
d1 = {'ciudad':'Valencia', 'temperatura':10, 'o2':1}
d2 = {'ciudad':'Barcelona', 'temperatura':8}
d3 = {'ciudad':'Valencia', 'temperatura':9}
d4 = {'ciudad':'Madrid', 'temperatura':10, 'humedad':80}
d5 = {'ciudad':'Sevilla', 'temperatura':15, 'humedad':50, 'co2':6}
d6 = {'ciudad':'Valencia', 'temperatura':10, 'humedad':90, 'co2':10}
7
ls_data = [d1, d2, d3, d4, d5, d6] # lista de diccionarios
df_data = pd.DataFrame(ls_data, index = list('abcdef'))
display(df_data)
# Out:
#       ciudad  temperatura   o2  humedad   co2
# a   Valencia           10  1.0      NaN   NaN
# b  Barcelona            8  NaN      NaN   NaN
# c   Valencia            9  NaN      NaN   NaN
# d     Madrid           10  NaN     80.0   NaN
# e    Sevilla           15  NaN     50.0   6.0
# f   Valencia           10  NaN     90.0  10.0

# %%
# Acceso a un valor concreto por indice posicional [row, col]
print(df_data.iloc[1,1])
# Acceso a todos los valores hasta un índice por enteros
display(df_data.iloc[:3,:4])
# Acceso a datos de manera explícita, indice semantico (se incluyen)
display(df_data.loc['a', 'temperatura'])
display(df_data.loc[:'c', :'o2'])
display(df_data.loc[:'c', 'temperatura':'o2'])
display(df_data.loc[:, ['ciudad','o2']])
# Out:
# 8
#       ciudad  temperatura   o2  humedad
# a   Valencia           10  1.0      NaN
# b  Barcelona            8  NaN      NaN
# c   Valencia            9  NaN      NaN
# np.int64(10)
#       ciudad  temperatura   o2
# a   Valencia           10  1.0
# b  Barcelona            8  NaN
# c   Valencia            9  NaN
#    temperatura   o2
# a           10  1.0
# b            8  NaN
# c            9  NaN
#       ciudad   o2
# a   Valencia  1.0
# b  Barcelona  NaN
# c   Valencia  NaN
# d     Madrid  NaN
# e    Sevilla  NaN
# f   Valencia  NaN

# %%
# indexación con nombre de columna (por columnas)
print(df_data['ciudad']) #--> Series
display(df_data[['ciudad', 'o2']])
# Out:
# a     Valencia
# b    Barcelona
# c     Valencia
# d       Madrid
# e      Sevilla
# f     Valencia
# Name: ciudad, dtype: object
#       ciudad   o2
# a   Valencia  1.0
# b  Barcelona  NaN
# c   Valencia  NaN
# d     Madrid  NaN
# e    Sevilla  NaN
# f   Valencia  NaN

# %%
# indexación con índice posicional (no permitido!). Esto busca columna.
df_data.iloc[0]
# Out:
# ciudad         Valencia
# temperatura          10
# o2                  1.0
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object

# %%
# indexar por posición con 'iloc'
print(df_data.iloc[0]) #--> Series de la primera fila (qué marca los índices)
# Out:
# ciudad         Valencia
# temperatura          10
# o2                  1.0
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object

# %%
# indexar semántico con 'loc'
df_data.loc['a'] #--> Series de la fila con índice 'a'
# Out:
# ciudad         Valencia
# temperatura          10
# o2                  1.0
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object

# %%
# indexar semántico con 'loc'
df_data.loc[:'b'] #--> DataFrame de la fila con índice 'a' y 'b'
# Out:
#       ciudad  temperatura   o2  humedad  co2
# a   Valencia           10  1.0      NaN  NaN
# b  Barcelona            8  NaN      NaN  NaN

# %%
df_data.loc[:'b'].loc[:,["o2", "humedad"]] # slicing anidado
# Out:
#     o2  humedad
# a  1.0      NaN
# b  NaN      NaN

# %%
# si se modifica una porcion del dataframe se modifica el original (referencia)
display(df_data)

serie = df_data.loc['a']
print(serie)

serie.iloc[2] = 3000  # setting with copy warning!!!
display(df_data)

# copiar data frame
df_2 = df_data.loc['a'].copy()
# Out:
#       ciudad  temperatura   o2  humedad   co2
# a   Valencia           10  1.0      NaN   NaN
# b  Barcelona            8  NaN      NaN   NaN
# c   Valencia            9  NaN      NaN   NaN
# d     Madrid           10  NaN     80.0   NaN
# e    Sevilla           15  NaN     50.0   6.0
# f   Valencia           10  NaN     90.0  10.0
# ciudad         Valencia
# temperatura          10
# o2                  1.0
# humedad             NaN
# co2                 NaN
# Name: a, dtype: object
# C:\Users\santi\AppData\Local\Temp\ipykernel_8888\3731434400.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   serie.iloc[2] = 3000  # setting with copy warning!!!
#       ciudad  temperatura   o2  humedad   co2
# a   Valencia           10  1.0      NaN   NaN
# b  Barcelona            8  NaN      NaN   NaN
# c   Valencia            9  NaN      NaN   NaN
# d     Madrid           10  NaN     80.0   NaN
# e    Sevilla           15  NaN     50.0   6.0
# f   Valencia           10  NaN     90.0  10.0

# %%
# ambos aceptan `axis` como argumento
# df_data.iloc(axis=1)[0] #--> todos los valores asignados a la primera columna
# columna 'ciudad'
df_data.loc(axis=1)['ciudad']  #--> equivalente frame['ciudad']
# Out:
# a     Valencia
# b    Barcelona
# c     Valencia
# d       Madrid
# e      Sevilla
# f     Valencia
# Name: ciudad, dtype: object

# %%
# qué problema puede tener este fragmento?
frame = pd.DataFrame({"Name" : ['Carlos','Pedro'], "Age" : [34,22]},
index=[1,0])
display(frame)
# Out:
#      Name  Age
# 1  Carlos   34
# 0   Pedro   22

# %%
# por defecto, pandas interpreta índice posicional--> error en frames
# cuando hay posible ambigüedad, utilizar loc y iloc
print('Primera fila\n')
print(frame.iloc[0])
print('\nElemento con index 0\n')
print(frame.loc[0])
# Out:
# Primera fila
#
# Name    Carlos
# Age         34
# Name: 1, dtype: object
#
# Elemento con index 0
#
# Name    Pedro
# Age        22
# Name: 0, dtype: object

# %% [markdown]
# ### 4.4 Objeto Index de Pandas

# %%
# Contrucción de índices
ind = pd.Index([2, 3, 5, 23, 26])
# recuperar datos
print(ind[3])
print(ind[::2])
# Out:
# 23
# Index([2, 5, 26], dtype='int64')

# %%
# usar un objeto index al crear dataframe
frame = pd.DataFrame({"Name" : ['Carlos','Pedro', 'Manolo', 'Luis', 'Alberto'],
"Age" : [34,22,15,55,23]}, index=ind)
display(frame)
# Out:
#        Name  Age
# 2    Carlos   34
# 3     Pedro   22
# 5    Manolo   15
# 23     Luis   55
# 26  Alberto   23

# %%
# Son inmutables! No se modifican los datos.
ind[3] = 8
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[100], line 2
#       1 # Son inmutables! No se modifican los datos.
# ----> 2 ind[3] = 8
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5383, in Index.__setitem__(self, key, value)
#    5381 @final
#    5382 def __setitem__(self, key, value) -> None:
# -> 5383     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
import pandas as pd

# definir index (porque el ejercicio anterior dependía de esto)
index = ['a', 'b', 'c', 'd', 'e']

# change index column
frame = pd.DataFrame(
    {"Name": ['Carlos','Pedro','Manolo','Luis','Ana'],
     "Age": [34,22,15,55,23]},
    index=index
)

display(frame)

frame.set_index("Age", inplace=True)
display(frame)
# Out:
#      Name  Age
# a  Carlos   34
# b   Pedro   22
# c  Manolo   15
# d    Luis   55
# e     Ana   23
#        Name
# Age
# 34   Carlos
# 22    Pedro
# 15   Manolo
# 55     Luis
# 23      Ana

# %% [markdown]
# ### 4.5 Slicing

# %%
# slice por filas
d_and_d_characters = {'Name' : ['bundenth','theorin','barlok'], 'Strength' :
[10,12,19], 'Wisdom' : [20,13,6]}
character_data = pd.DataFrame(d_and_d_characters, index=['a','b','c'])
display(character_data)
display(character_data[:-1])
display(character_data[1:2])
# Out:
#        Name  Strength  Wisdom
# a  bundenth        10      20
# b   theorin        12      13
# c    barlok        19       6
#        Name  Strength  Wisdom
# a  bundenth        10      20
# b   theorin        12      13
#       Name  Strength  Wisdom
# b  theorin        12      13

# %%
# slicing para columnas
display(character_data[['Name','Wisdom']])
# Out:
#        Name  Wisdom
# a  bundenth      20
# b   theorin      13
# c    barlok       6

# %%
#slicing con 'loc' e 'iloc'
display(character_data.iloc[1:])
display(character_data.loc[:'b','Name':'Strength'])
# Out:
#       Name  Strength  Wisdom
# b  theorin        12      13
# c   barlok        19       6
#        Name  Strength
# a  bundenth        10
# b   theorin        12

# %% [markdown]
# ¿Cómo filtrar filas y columnas? Por ejemplo, para todos los personajes, obtener ‘Name’ y ‘Strength’

# %%
# usando 'loc' para hacer slicing
display(character_data.loc[:,'Name':'Strength'])
# Out:
#        Name  Strength
# a  bundenth        10
# b   theorin        12
# c    barlok        19

# %%
# usando 'loc' para buscar específicamente filas y columnas
display(character_data.loc[ ['a','c'], ['Name','Wisdom'] ])
# Out:
#        Name  Wisdom
# a  bundenth      20
# c    barlok       6

# %%
# lo mismo con 'iloc'?
display(character_data.iloc[[0,2],[0,2]])
display(character_data.iloc[[0,-1],[0,-1]])
# Out:
#        Name  Wisdom
# a  bundenth      20
# c    barlok       6
#        Name  Wisdom
# a  bundenth      20
# c    barlok       6

# %%
# lista de los personajes con el atributo Strength > 11
display(character_data.loc[character_data['Strength'] > 11, ['Name',
'Strength']])
# Out:
#       Name  Strength
# b  theorin        12
# c   barlok        19

# %%
# listar los personajes con Strength > 15 o Wisdom > 15
display(character_data.loc[(character_data['Strength'] > 15) |
(character_data['Wisdom'] > 15)])
# Out:
#        Name  Strength  Wisdom
# a  bundenth        10      20
# c    barlok        19       6

# %% [markdown]
# ### 5 Cargar y guardar datos en pandas

# %%
# Guardar a csv
import os
ruta = os.path.join("res" ,"o_d_d_characters.csv")
#character_data.to_csv(ruta, sep=';') # sep por defecto: ','

# %%
loaded = pd.read_csv(ruta, sep=';')
display(loaded)
# Out:
#   Unnamed: 0      Name  Strength  Wisdom
# 0          a  bundenth        10      20
# 1          b   theorin        12      13
# 2          c    barlok        19       6

# %%
ruta = os.path.join("res","titanic.csv")

# %%
titanic = pd.read_csv(ruta, sep=',')
display(titanic)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
loaded = pd.read_csv(ruta, sep=',', index_col = 0)
display(loaded)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# otros argumentos to_csv()

# %% [markdown]
# * na_rep=‘string’–> representar valores NaN en el archivo csv

# %% [markdown]
# otros argumentos read_csv()

# %% [markdown]
# * na_values=‘string

# %% [markdown]
# Pandas también ofrece funciones para leer/guardar a otros formatos estándares: JSON, HDF5 o
# Excel en su API

# %% [markdown]
# ### 6 Ejemplo práctico en pandas

# %% [markdown]
# * MovieLens dataset
# * Reviews de películas
# * 1millón de entradas
# * Datos demográficos de usuarios

# %%
import numpy as np
import pandas as pd
import zipfile # para descomprimir archivos zip
import urllib.request # para descargar de URL
import os
# descargar MovieLens dataset
url = 'http://files.grouplens.org/datasets/movielens/ml-1m.zip'
ruta = os.path.join("res", "ml-1m.zip")
urllib.request.urlretrieve(url, ruta)
# Out:
# ('res\\ml-1m.zip', <http.client.HTTPMessage at 0x2d3ea6d1940>)

# %%
import os
import zipfile

# definir ruta del zip (debe estar en la misma carpeta del notebook)
ruta = "archivo.zip"   # ⚠️ cambia por el nombre real

# descomprimiendo archivo zip
ruta_ext = os.path.join("res")

with zipfile.ZipFile(ruta, 'r') as z:
    print("Extracting all files...")
    z.extractall(ruta_ext)  # destino
    print("Done!")

# take a look at readme y revisar formatos
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[33], line 10
#       7 # descomprimiendo archivo zip
#       8 ruta_ext = os.path.join("res")
# ---> 10 with zipfile.ZipFile(ruta, 'r') as z:
#      11     print("Extracting all files...")
#      12     z.extractall(ruta_ext)  # destino
#
# File C:\ProgramData\anaconda3\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'archivo.zip'

# %%
ruta_users = os.path.join("res", "ml-1m", "users.dat")
11
users_dataset = pd.read_csv(ruta_users, sep='::', index_col=0, engine='python')
display(users_dataset)
# Out:
#       F  1.1  10  48067
# 1
# 2     M   56  16  70072
# 3     M   25  15  55117
# 4     M   45   7  02460
# 5     M   25  20  55455
# 6     F   50   9  55117
# ...  ..  ...  ..    ...
# 6036  F   25  15  32603
# 6037  F   45   1  76006
# 6038  F   56   1  14706
# 6039  F   45   0  01060
# 6040  M   25   6  11106
#
# [6039 rows x 4 columns]

# %%
# Varios problemas
# sin cabecera! primer valor se ha perdido
# las columnas no tienen nombres
pd.read_csv?
# Out:
# Object `pd.read_csv` not found.

# %%
import pandas as pd

# especificar nombres, cargar sin cabecera
users_dataset = pd.read_csv(ruta_users, sep="::", index_col=0,
                            header=None, names=['UserID','Gender','Age','Occupation','Zip-code'],
                            engine='python')

display(users_dataset)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import pandas as pd
#       3 # especificar nombres, cargar sin cabecera
# ----> 4 users_dataset = pd.read_csv(ruta_users, sep="::", index_col=0,
#       5                             header=None, names=['UserID','Gender','Age','Occupation','Zip-code'],
#       6                             engine='python')
#       8 display(users_dataset)
#
# NameError: name 'ruta_users' is not defined
